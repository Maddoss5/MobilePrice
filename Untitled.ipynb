# %%
import pandas as pd 
from sklearn import tree

# %%
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('train.csv')

# %%
data=(data-data.min())/(data.max()-data.min())

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores  ...  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  ...   0.010204  0.170895
# ...

# %%
data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
noneed=['blue','m_dep','mobile_wt','pc']

# %%
data.drop(noneed,axis=1)
# Out:
#       battery_power  clock_speed  dual_sim        fc  four_g  int_memory  \
# 0          0.227789         0.68       0.0  0.052632     0.0    0.080645
# 1          0.347361         0.00       1.0  0.000000     1.0    0.822581
# 2          0.041416         0.00       1.0  0.105263     1.0    0.629032
# 3          0.076152         0.80       0.0  0.000000     0.0    0.129032
# 4          0.881764         0.28       0.0  0.684211     1.0    0.677419
# ...             ...          ...       ...       ...     ...         ...
# 1995       0.195725         0.00       1.0  0.000000     1.0    0.000000
# 1996       0.977956         0.84       1.0  0.000000     0.0    0.596774
# 1997       0.941884         0.16       1.0  0.052632     1.0    0.548387
# 1998       0.675351         0.16       0.0  0.210526     1.0    0.709677
# 1999       0.006012         0.60       1.0  0.263158     1.0    0.693548
#
#        n_cores  px_height  px_width       ram      sc_h      sc_w  talk_time  \
# ...

# %%
X=data.iloc[:,:-1]
Y=data.iloc[:,-1]

# %%
X
# Out:
#       battery_power  blue  clock_speed  dual_sim        fc  four_g  \
# 0          0.227789   0.0         0.68       0.0  0.052632     0.0
# 1          0.347361   1.0         0.00       1.0  0.000000     1.0
# 2          0.041416   1.0         0.00       1.0  0.105263     1.0
# 3          0.076152   1.0         0.80       0.0  0.000000     0.0
# 4          0.881764   1.0         0.28       0.0  0.684211     1.0
# ...             ...   ...          ...       ...       ...     ...
# 1995       0.195725   1.0         0.00       1.0  0.000000     1.0
# 1996       0.977956   1.0         0.84       1.0  0.000000     0.0
# 1997       0.941884   0.0         0.16       1.0  0.052632     1.0
# 1998       0.675351   0.0         0.16       0.0  0.210526     1.0
# 1999       0.006012   1.0         0.60       1.0  0.263158     1.0
#
#       int_memory     m_dep  mobile_wt   n_cores    pc  px_height  px_width  \
# 0       0.080645  0.555556   0.900000  0.142857  0.10   0.010204  0.170895
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42)

# %%
dec=tree.DecisionTreeRegressor()

# %%
dec.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predicts=dec.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import r2_score

# %%
r2_score(predicts, y_test)
# Out:
# 0.8921326582325564

# %%
from sklearn.linear_model import LinearRegression

# %%
lin=LinearRegression()

# %%
lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predicts=lin.predict(X_test)

# %%
r2_score(predicts, y_test)
# Out:
# 0.9127921520465196

# %%
ha=17

# %%
print(predicts[ha],y_test.iloc[ha])
# Out:
# 1.1554785988189673 1.0
